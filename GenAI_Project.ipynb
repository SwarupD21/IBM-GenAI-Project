# %% [markdown]
# <a href="https://colab.research.google.com/github/SwarupD21/IBM-GenAI-Project/blob/main/GenAI_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate bitsandbytes

# %%
# !pip install -q transformers accelerate

# %%
# !pip install -U transformers accelerate sentencepiece

# %%
from transformers import pipeline
import torch

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

class CustomText2TextGenerator:
    def __init__(self, model_name, max_new_tokens=120):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        # AutoModelForSeq2SeqLM is appropriate for T5 (encoder-decoder) models
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
        self.max_new_tokens = max_new_tokens

        # Move model to GPU if available, otherwise keep on CPU
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model.to(self.device)

    def __call__(self, prompt):
        inputs = self.tokenizer(prompt, return_tensors="pt").to(self.device)

        outputs = self.model.generate(
            **inputs,
            max_new_tokens=self.max_new_tokens
        )
        generated_text = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
        return [{"generated_text": generated_text}]

generator = CustomText2TextGenerator("google/flan-t5-xl", max_new_tokens=120)
# Out:
# Loading weights:   0%|          | 0/558 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
def sustainable_advisor(user_input):

    prompt = f"""
Answer the question with eco-friendly tips.

Question: {user_input}
"""

    result = generator(prompt)

    return result[0]["generated_text"]

# %%
question = "How can I reduce plastic usage in daily life?"
answer = sustainable_advisor(question)
print(answer)
# Out:
# Use reusable bags.

# %%
question = "How can I save electricity at home?"
answer = sustainable_advisor(question)
print(answer)
# Out:
# Use a dimmer switch on your lights.
